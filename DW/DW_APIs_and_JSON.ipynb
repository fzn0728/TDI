# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %% [markdown]
# # Consuming APIs (and JSON)
# <!-- requirement: secrets/twitter_secrets.json.sample -->
#
# Consuming APIs is supposed to be easy (that's the point of having an API).
#
# Let's look at a simple example of consuming a JSON API.  The example we'll look at is a *geocoder*: That is, a service for converting between addresses and normalized geographic information (e.g. latitude and longitude).  Going from addresses to normalized form is "forward geocoding" and going the other way is "reverse geocoding".
#
# We'll interact with a free (and non-authenticated) geocoder run by OpenStreetMap.  The geocoded information is available by sending a GET request to <tt>http:&#8203;//nominatim.openstreetmap.org/search?q=<i>address</i>&addressdetails=1&format=json</tt>.  The portion before the question mark (`http://nominatim.openstreetmap.org/search`) is the endpoint on the server, while the portion following, known as the *query string*, contains the data being sent to the server.  (Thus, a GET request can be repeated simply by requesting the same URL again.  In contrast, the data sent in a POST request is contained in the request body, not in the URL.)
#
# As is typical, the query string consists of several key=value pairs, separated by ampersands.  The requested address is specified with the `q` key in this case.  Some characters, like the spaces and commas, cannot be using in the URL, so they must be enoded with the `urllib2.quote()` function.

# %%
import urllib2

address = "1600 Pennsylvania Avenue, Washington, DC"
urllib2.quote(address)
# Out:
# '1600%20Pennsylvania%20Avenue%2C%20Washington%2C%20DC'

# %%
url = "http://nominatim.openstreetmap.org/search?q=%s&addressdetails=1&format=json" % urllib2.quote(address)
url
# Out:
# 'http://nominatim.openstreetmap.org/search?q=1600%20Pennsylvania%20Avenue%2C%20Washington%2C%20DC&addressdetails=1&format=json'

# %% [markdown]
# We can request this URL with the `urlopen()` function, which returns a stream we can read from.

# %%
data = urllib2.urlopen(url).read()
data
# Out:
# '[{"place_id":"205726488","licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http:\\/\\/www.openstreetmap.org\\/copyright","osm_type":"way","osm_id":"238241022","boundingbox":["38.8974898","38.897911","-77.0368541","-77.0362525"],"lat":"38.8976998","lon":"-77.0365533886228","display_name":"White House, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20500, United States of America","class":"office","type":"government","importance":1.0276757387296,"address":{"address29":"White House","house_number":"1600","pedestrian":"Pennsylvania Avenue Northwest","city":"Washington","state":"District of Columbia","postcode":"20500","country":"United States of America","country_code":"us"}},{"place_id":"199809710","licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http:\\/\\/www.openstreetmap.org\\/copyright","osm_type":"way","osm_id":"238241023","boundingbox":["38.8973238","38.8974301","-77.0374623","-77.0373527"],"lat":"38.8973793","lon":"-77.0374074357536","display_name":"The Oval Office, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20006, United States of America","class":"office","type":"government","importance":0.84571630620192,"address":{"address29":"The Oval Office","house_number":"1600","pedestrian":"Pennsylvania Avenue Northwest","city":"Washington","state":"District of Columbia","postcode":"20006","country":"United States of America","country_code":"us"}},{"place_id":"205726484","licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http:\\/\\/www.openstreetmap.org\\/copyright","osm_type":"way","osm_id":"238241016","boundingbox":["38.8973238","38.8976897","-77.0378225","-77.0372951"],"lat":"38.8974983","lon":"-77.0375589052579","display_name":"The West Wing, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20500, United States of America","class":"office","type":"government","importance":0.7714973276097,"address":{"address29":"The West Wing","house_number":"1600","pedestrian":"Pennsylvania Avenue Northwest","city":"Washington","state":"District of Columbia","postcode":"20500","country":"United States of America","country_code":"us"}},{"place_id":"205726486","licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http:\\/\\/www.openstreetmap.org\\/copyright","osm_type":"way","osm_id":"238241018","boundingbox":["38.8973817","38.897768","-77.0357842","-77.0355016"],"lat":"38.89756155","lon":"-77.0356428619915","display_name":"The East Wing, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20500, United States of America","class":"office","type":"government","importance":0.71661565540093,"address":{"address29":"The East Wing","house_number":"1600","pedestrian":"Pennsylvania Avenue Northwest","city":"Washington","state":"District of Columbia","postcode":"20500","country":"United States of America","country_code":"us"}},{"place_id":"28364788","licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http:\\/\\/www.openstreetmap.org\\/copyright","osm_type":"node","osm_id":"2633633933","boundingbox":["38.897668","38.897768","-77.0365981","-77.0364981"],"lat":"38.897718","lon":"-77.0365481","display_name":"1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20006, United States of America","class":"man_made","type":"flagpole","importance":0.421,"address":{"house_number":"1600","pedestrian":"Pennsylvania Avenue Northwest","city":"Washington","state":"District of Columbia","postcode":"20006","country":"United States of America","country_code":"us"}},{"place_id":"155673897","licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http:\\/\\/www.openstreetmap.org\\/copyright","osm_type":"way","osm_id":"432096036","boundingbox":["38.8790168","38.879436","-76.9824941","-76.9815744"],"lat":"38.87922555","lon":"-76.9819500245811","display_name":"1600, Pennsylvania Avenue Southeast, Hill East, Washington, District of Columbia, 20003, United States of America","class":"building","type":"yes" ...

# %% [markdown]
# The result was returned to us in the form of JSON. JSON is JavaScript Object Notation&mdash;it's a human readable text-based format for transmitting key-value pairs (and strings, numbers, and arrays). The json package lets us convert between this and Python's native dictionaries, etc.

# %%
import simplejson as json

json.loads(data)
# Out:
# [{'address': {'address29': 'White House',
#    'city': 'Washington',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'house_number': '1600',
#    'pedestrian': 'Pennsylvania Avenue Northwest',
#    'postcode': '20500',
#    'state': 'District of Columbia'},
#   'boundingbox': ['38.8974898', '38.897911', '-77.0368541', '-77.0362525'],
#   'class': 'office',
#   'display_name': 'White House, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20500, United States of America',
#   'importance': 1.0276757387296,
#   'lat': '38.8976998',
#   'licence': u'Data \xa9 OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   'lon': '-77.0365533886228',
#   'osm_id': '238241022',
#   'osm_type': 'way',
#   'place_id': '205726488',
#   'type': 'government'},
#  {'address': {'address29': 'The Oval Office',
#    'city': 'Washington',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'house_number': '1600',
#    'pedestrian': 'Pennsylvania Avenue Northwest',
#    'postcode': '20006',
#    'state': 'District of Columbia'},
#   'boundingbox': ['38.8973238', '38.8974301', '-77.0374623', '-77.0373527'],
#   'class': 'office',
#   'display_name': 'The Oval Office, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20006, United States of America',
#   'importance': 0.84571630620192,
#   'lat': '38.8973793',
#   'licence': u'Data \xa9 OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   'lon': '-77.0374074357536',
#   'osm_id': '238241023',
#   'osm_type': 'way',
#   'place_id': '199809710',
#   'type': 'government'},
#  {'address': {'address29': 'The West Wing',
#    'city': 'Washington',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'house_number': '1600',
#    'pedestrian': 'Pennsylvania Avenue Northwest',
#    'postcode': '20500',
#    'state': 'District of Columbia'},
#   'boundingbox': ['38.8973238', '38.8976897', '-77.0378225', '-77.0372951'],
#   'class': 'office',
#   'display_name': 'The West Wing, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20500, United States of America',
#   'importance': 0.7714973276097,
#   'lat': '38.8974983',
#   'licence': u'Data \xa9 OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   'lon': '-77.0375589052579',
#   'osm_id': '238241016',
#   'osm_type': 'way',
#   'place_id': '205726484',
#   'type': 'government'},
#  {'address': {'address29': 'The East Wing',
#    'city': 'Washington',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'house_number': '1600',
#    'pedestrian': 'Pennsylvania Avenue Northwest',
#    'postcode': '20500',
#    'state': 'District of Columbia'},
#   'boundingbox': ['38.8973817', '38.897768', '-77.0357842', '-77.0355016'],
#   'class': 'office',
#   'display_name': 'The East Wing, 1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20500, United States of America',
#   'importance': 0.71661565540093,
#   'lat': '38.89756155',
#   'licence': u'Data \xa9 OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   'lon': '-77.0356428619915',
#   'osm_id': '238241018',
#   'osm_type': 'way',
#   'place_id': '205726486',
#   'type': 'government'},
#  {'address': {'city': 'Washington',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'house_number': '1600',
#    'pedestrian': 'Pennsylvania Avenue Northwest',
#    'postcode': '20006',
#    'state': 'District of Columbia'},
#   'boundingbox': ['38.897668', '38.897768', '-77.0365981', '-77.0364981'],
#   'class': 'man_made',
#   'display_name': '1600, Pennsylvania Avenue Northwest, Washington, District of Columbia, 20006, United States of America',
#   'importance': 0.421,
#   'lat': '38.897718',
#   'licence': u'Data \xa9 OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   'lon': '-77.0365481',
#   'osm_id': '2633633933',
#   'osm_type': 'node',
#   'place_id': '28364788',
#   'type': 'flagpole'},
#  {'address': {'city': 'Washington',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'house_number': '1600',
#    'neighbourhood': 'Hill East',
#    'postcode': '20003',
#    'road': 'Pennsylvania Avenue Southeast',
#    'state': 'District of Columbia'},
#   'boundingbox': ['38.8790168', '38.879436', '-76.9824941', '-76.9815744'],
#   'class': 'building',
#   'display_name': '1600, Pennsylvania Avenue Southeast, Hill East, Washington, District of Columbia, 20003, United States of America',
#   'importance': 0.421,
#   'lat': '38.87922555',
#   'licence': u'Data \xa9 OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   'lon': '-76.9819500245811',
#   'osm_id': '432096036',
#   'osm_type': 'way',
#   'place_id': '155673897',
#   'type': 'yes'}]

# %%
json.loads(data)[0]['boundingbox']
# Out:
# ['38.8974898', '38.897911', '-77.0368541', '-77.0362525']

# %% [markdown]
# Note that this was a public API, with no authentication.  We'll go through an example of the code for an authenticated API at the end -- the example will be the free Twitter stream.  (The reason we didn't do this up front is that you can't run the code without signing up for an API key, etc.)

# %% [markdown]
# ## Handling URL parameters
#
# `urllib2` module requires an enormous amount of work to perform the simplest of tasks. The `requests` library provides a higher-level way to do web requests. This is already nice in examples, like the above, where we need to encode parameters into the URL.  It is even more convenient when there are also `POST` parameters (or cookies, or authentication, or...) involved.  (Don't worry if you don't know what that means.)

# %%
import requests
def geocode(address):
    params = { 'format'        :'json', 
               'addressdetails': 1, 
               'q'             : address}
    return requests.get('http://nominatim.openstreetmap.org/search', params=params)

response = geocode("107 Page St., San Francisco")

# %% [markdown]
# The parameters are automatically encoded and assembled into the query string.

# %%
response.url
# Out:
# u'http://nominatim.openstreetmap.org/search?q=107+Page+St.%2C+San+Francisco&addressdetails=1&format=json'

# %% [markdown]
# The raw response is available...

# %%
response.text
# Out:
# u'[{"place_id":"164709909","licence":"Data \xa9 OpenStreetMap contributors, ODbL 1.0. http:\\/\\/www.openstreetmap.org\\/copyright","osm_type":"way","osm_id":"32121427","boundingbox":["37.773928208333","37.774028208333","-122.42263933333","-122.42253933333"],"lat":"37.7739782083333","lon":"-122.422589333333","display_name":"107, Page Street, Hayes Valley, SF, California, 94102, United States of America","class":"place","type":"house","importance":0.311,"address":{"house_number":"107","road":"Page Street","neighbourhood":"Hayes Valley","city":"SF","county":"SF","state":"California","postcode":"94102","country":"United States of America","country_code":"us"}}]'

# %% [markdown]
# ...but it can also be converted to JSON.

# %%
response.json()
# Out:
# [{u'address': {u'city': u'SF',
#    u'country': u'United States of America',
#    u'country_code': u'us',
#    u'county': u'SF',
#    u'house_number': u'107',
#    u'neighbourhood': u'Hayes Valley',
#    u'postcode': u'94102',
#    u'road': u'Page Street',
#    u'state': u'California'},
#   u'boundingbox': [u'37.773928208333',
#    u'37.774028208333',
#    u'-122.42263933333',
#    u'-122.42253933333'],
#   u'class': u'place',
#   u'display_name': u'107, Page Street, Hayes Valley, SF, California, 94102, United States of America',
#   u'importance': 0.311,
#   u'lat': u'37.7739782083333',
#   u'licence': u'Data \xa9 OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#   u'lon': u'-122.422589333333',
#   u'osm_id': u'32121427',
#   u'osm_type': u'way',
#   u'place_id': u'164709909',
#   u'type': u'house'}]

# %%
response.json()[0]['boundingbox']
# Out:
# [u'37.773928208333',
#  u'37.774028208333',
#  u'-122.42263933333',
#  u'-122.42253933333']

# %% [markdown]
# **Exercise:** The National Weather Service operates a free API for weather information.  A sample request looks like this: `http://forecast.weather.gov/MapClick.php?lat=37.7739&lon=-122.4225&FcstType=json`.
#
# Use the geocoder to write a function
#
#         def weather_at_address(address):
#             ....
#
# that gets the current weather (temperature, cloudy or not) from a human-entered address.

# %% [markdown]
# ## Authenticated APIs
#
# Lots of interesting APIs are free (or at least free for moderate use) but still require you to register first.  The `requests` library (together with some supporting ones, e.g. `requests_oauthlib`) make it easy to consume these too.
#
# **Exercise:** In order to access the Twitter API, you must first sign up: create an app on http://apps.twitter.com, get an access token, et voila, you have your shiny new credentials -- consisting of four pieces of data. The file /secrets/twitter_secrets.json.sample in the datacourse repo has the format template; then rename the file to have a .nogit extension to prevent it being tracked in the repository.

# %%
from requests_oauthlib import OAuth1

with open("secrets/twitter_secrets.json.nogit") as fh:
    secrets = json.loads(fh.read())

# create an auth object
auth = OAuth1(
    secrets["api_key"],
    secrets["api_secret"],
    secrets["access_token"],
    secrets["access_token_secret"]
)

# %%
r = requests.get(
    "https://api.twitter.com/1.1/friends/ids.json",
    auth=auth,
    params={'screen_name' : 'tianhuil'}
)
michaels_friends=r.json()
michaels_friends
# Out:
# {u'ids': [841603660962496512,
#   462591064,
#   332367960,
#   82079120,
#   783199393,
#   95630108,
#   1300236846,
#   56695818,
#   2266344997,
#   19062108,
#   729842069418561537,
#   2316330369,
#   191951266,
#   61383181,
#   3098988520,
#   30951828,
#   64700439,
#   125106411,
#   3418151627,
#   2904700968,
#   761286564462800897,
#   737555105231208448,
#   2458503919,
#   737142202481016832,
#   3721437254,
#   94532914,
#   525677604,
#   819329885164343296,
#   1146719540,
#   1259805054,
#   811209223715639296,
#   838950174873505792,
#   838964330255237121,
#   559345754,
#   121198602,
#   426619893,
#   10124492,
#   165013427,
#   373740452,
#   15494489,
#   38108253,
#   2732901378,
#   219722355,
#   836773201086590976,
#   1014480217,
#   3079119829,
#   18720381,
#   213306799,
#   827587449941524480,
#   32897323,
#   417005772,
#   2807681672,
#   3241705728,
#   790604182944358401,
#   746391965240016897,
#   7648872,
#   800828820769095680,
#   424081186,
#   2799159231,
#   100206544,
#   2502128419,
#   824295666784423937,
#   2495841841,
#   1157373200,
#   569517376,
#   14112036,
#   213156908,
#   15542377,
#   733407223,
#   541171903,
#   70513691,
#   20257992,
#   2991191267,
#   8513352,
#   14303901,
#   3198265840,
#   3512663897,
#   64253234,
#   20447174,
#   25260440,
#   2971681845,
#   127487355,
#   1302204846,
#   488349425,
#   614624536,
#   148477841,
#   401655370,
#   333438887,
#   4417338814,
#   701838242627235840,
#   23611168,
#   21467391,
#   2790362202,
#   18518601,
#   2742938653,
#   36533993,
#   3065669909,
#   35480690,
#   14066472,
#   798116,
#   361013072,
#   65667476,
#   21172531,
#   333516125,
#   84917467,
#   304644240,
#   284189052,
#   841437061,
#   2154693428,
#   763476518802776069,
#   24961070,
#   10968372,
#   730803,
#   23935538,
#   2214230930,
#   1977619399,
#   2432616608,
#   2793160065,
#   13290572,
#   4157279601,
#   1517126281,
#   481164619,
#   18666236,
#   295264798,
#   1412888750,
#   102392745,
#   18479593,
#   277115268,
#   1978859582,
#   234920068,
#   1140834680,
#   715864432535068672,
#   401942969,
#   4493531135,
#   482324496,
#   35236870,
#   283711814,
#   752793193490579457,
#   723446317674962944,
#   4256453355,
#   343844568,
#   82313947,
#   45565688,
#   19365210,
#   3927612855,
#   16183006,
#   555031989,
#   3502970478,
#   1376926921,
#   4079613614,
#   3229980963,
#   2902092937,
#   46098726,
#   1480718904,
#   62526165,
#   22775202,
#   320765126,
#   3417561490,
#   1430358516,
#   2576842118,
#   1291879802,
#   2892695615,
#   705765217,
#   908360509,
#   1941897590,
#   453557650,
#   9644132,
#   4686586766,
#   86206084,
#   454587223,
#   4866966137,
#   3029046017,
#   124797824,
#   221318833,
#   1182690330,
#   4619684853,
#   739902470864941058,
#   128472107,
#   1543765200,
#   21591454,
#   3012369622,
#   3346369193,
#   4860411297,
#   14846380,
#   2795213426,
#   299965657,
#   920434452,
#   8062702,
#   752258740435333121,
#   1605693206,
#   759606437538660352,
#   94534890,
#   721014900227637249,
#   1238848753,
#   25668843,
#   96573481,
#   4201846887,
#   734690974534934528,
#   225143034,
#   143851769,
#   31004648,
#   42624684,
#   87232263,
#   3063930567,
#   2570805289,
#   67043272,
#   4693455169,
#   724611831785000960,
#   511740616,
#   191550813,
#   906203226,
#   3319142458,
#   11993022,
#   2870676279,
#   116830375,
#   2360980238,
#   481852345,
#   2876443557,
#   746266972954865664,
#   38670373,
#   ...],
#  u'next_cursor': 0,
#  u'next_cursor_str': u'0',
#  u'previous_cursor': 0,
#  u'previous_cursor_str': u'0'}

# %% [markdown]
# Let's see all of Michael's friends.

# %%
r = requests.get(
    "https://api.twitter.com/1.1/friends/ids.json",
    auth=auth,
    params={'screen_name' : 'tianhuil'}
)
michaels_friends=r.json()

r2 = requests.post(
    'https://api.twitter.com/1.1/users/lookup.json',
    auth=auth,
    data={'user_id' : michaels_friends['ids'][:50]}
)
friends_info = r2.json()
[(f['screen_name'], f['name']) for f in friends_info]
# Out:
# [(u'roaldshilov1',
#   u'\u0413\u0430\u043b\u0438\u043d\u0430 \u041a\u0438\u0442\u0430\u0435\u0432\u0430'),
#  (u'LithanAcademy', u'Lithan Academy'),
#  (u'alexkistenev', u'Alex Kistenev'),
#  (u'cashklick', u'Cashklick Inc.'),
#  (u'SAwritersnet', u'SAWN'),
#  (u'NedKhawar', u'Naveed Khawar'),
#  (u'yashdeep3150', u'Yashdeep Chaudhary'),
#  (u'sarahdajanti', u'Sarah Dajanti'),
#  (u'mzohaib615', u'zohaib'),
#  (u'whymandesign', u'Whymandesign.com'),
#  (u'OReillyAI', u'OReillyAI'),
#  (u'david_elges', u'David Elges'),
#  (u'aha_irshi', u'Ahamed'),
#  (u'DavidtheData', u'David Zheng'),
#  (u'JacquesQuant', u'Jacques Joubert'),
#  (u'brunobotteon', u'Bruno B. Tomazela'),
#  (u'KofiDebrah', u'Kofi Debrah'),
#  (u'offmana', u'Jen Yo \U0001f310 \U0001f61c'),
#  (u'waltque', u'Walt Q.'),
#  (u'ajalburaidi', u'Abduljalil Abdullah'),
#  (u'thematttcarter', u'Matt Carter'),
#  (u'kcldo1thing', u'#kcldo1thing'),
#  (u'Donald_Lush', u'Donald Lush'),
#  (u'chidambara09', u'Chidambara .ML.'),
#  (u'natarpr', u'Prashant N'),
#  (u'jeroenterheerdt', u'Jeroen ter Heerdt'),
#  (u'pepetapia44', u'joetapia'),
#  (u'jdatascientist', u'Julio'),
#  (u'DataInfact', u'Data In fact'),
#  (u'theLegacyPrep', u'Edwyna Washington'),
#  (u'Lucky62058333', u'Lucky'),
#  (u'emedigutckax', u'Chloe Davidson'),
#  (u'radimf4ila', u'Hannah Buckland'),
#  (u'alemanzotti', u'Alessandro Manzotti'),
#  (u'rkjoseph', u'Rajit Joseph'),
#  (u'tara_house', u'Tara House'),
#  (u'secun', u'secun sexto'),
#  (u'severino33', u'rodrigo severino'),
#  (u'Divya_aigal', u'Divya Aigal'),
#  (u'scottedwards200', u'Scott Edwards'),
#  (u'm1db', u'Michael Banach'),
#  (u'sowasser', u'Sophia N. Wassermann'),
#  (u'melanthropics', u'Melanthropy'),
#  (u'voortdownmisca1', u'\u041a\u0438\u0440\u0438\u043b\u043b'),
#  (u'lbkgorr', u'Laura Orr'),
#  (u'TheHubHO', u'The Hub'),
#  (u'rbramley', u'Robin Bramley'),
#  (u'erangatennakoon', u'Eranga Tennakoon'),
#  (u'THE_SAP_BOT', u'SAP_BOT'),
#  (u'benjenkinsiv', u'Ben Jenkins')]

# %% [markdown]
# Requests also makes it easy to deal with simple streaming APIs.  Let's stream 100 tweets from the Twitter feed.

# %%
import sys
r_stream = requests.get('https://stream.twitter.com/1.1/statuses/sample.json', auth=auth, stream=True)
counter = 0
for line in r_stream.iter_lines():
    # filter out keep-alive new lines
    if not line:
        continue
    tweet = json.loads(line)
    if 'text' in tweet:
        counter +=1
        print tweet['text']
    sys.stdout.flush()
    if counter > 100:
        break
# Out:
# RT @UmaShan26058933: @SSAAGurukul gurukul ke bachche pure vishva me bapuji nam Rosan kar rahe hai #गौरक्षा_सबकी_जिम्मेदारी
# @dbrauer I see 91 wins
# 희망만이 인생을 유일하게 사랑하는 것이다.  (앙리 프레데릭 아미엘)
# RT @jillianmooree: A milkshake is fine https://t.co/hTJGfjNmTP
# スキャンした紙文書やPDFを、フォントや表・レイアウトはそのままで、ワードやエクセルに変換
# @yu_spl_be 根気強くアタックしないと振り向いてくれませんからね…💔💔💔
# RT @__Emichan___: 破産前「アメリカ横断ツアーが人気☆」
# ──てるみくらぶ破産──
# 社長「自力で対処してもらうしかない」
# 客「自力で」
# 環境「ガチのサバイバルツアー☆」
# 客「ガチのサバイバル」
# 現状：砂漠の真ん中でモーテルなし https://t.co/J5KD…
# Very apt quote for MPs like Ravindra Gaikwad &amp; greedy politicians like #KejriCheatsDelhi
#
# @mediacrooks https://t.co/13VA4VYKKl
# RT @Jiovanni___: No mediocrity 😉
# @TheAshBradley @FoxNews Wow....
# Its very sweet exo with babys aww!
# Saranghae exo !
#  😍😙😘😚❤❤❤❤
# #EXOinItaly #5YearsWithEXO https://t.co/VBPsAEsZZ2
# RT @Safir_305: َ
#
# يارب ، سجدتُ لك وأنا لم أراك ، و دعوتُك وأنا لم أراك ،
# وأستعنتُ بك وأنا لم أراك ، فأحسن لقائي بك حينما أراك 🎈 .
# RT @gcsamm: 41. Being called 'mi reina' 'amor' 'corazón' etc. makes me heart warm
# @Ga_Curty Obrigada :) Vc acha que o Zverev tem boas chances contra o Stan?
# RT @_kbigelow: are u even from milwaukee if u weren't cyberbullied by eric abercrombie tool richter
# Just posted a 1.00 mi row with @Runkeeper. Check it out! https://t.co/VhmTOl4AaJ #Runkeeper
# NÃO VOTO MAIS ENQUETE NENHUMA DAQUI
# @annyhiansdt QQ deu??
# https://t.co/Qlz5wAVL25
# @x0jennnn love you ❤️
# RT @Masse78: Volevo dire una cosa a quelli che "Domani è un altro giorno, vedrai andrà meglio":
#
# SIETE FALSI.
# @Mymisiku_ JAJAJAJA AY es verdad
# @27a03c322e0f43a baya
# RT @thegooglefact: Remove negative people from your life. The people you spend time with influence your attitude, thoughts and success more…
# 腹減った。
# RT @semi_kon: ヤギ https://t.co/FZMYT8nNRS
# RT @3li_mhmed: بتبقا وحشة اوي لما حد بتحبو ويتهان قدامك ومتعرفش تعملو حاجة وتساعدو
# RT @nusr_ett: Carpaccio #saltbae #saltlife https://t.co/59XNwXriEq
# RT @filmfare: #FilmfareExclusive!
#
# Here are some backstage pictures of Adonis @iHrithik slaying it at the #HELLOHallOfFame awards. https://…
# RT @NXBZL: la vérité ne résiste pas à l'alcool
# こいやセルリアン
# RT @viewaranya: เหมือนแฟนที่ทะเลาะกัน จิ๊บบอกซวยกุทุกที #jaeyong https://t.co/Oh0lMtd4zV
# .@seanspicer reminds me of the Duke &amp; Duke weasel #commodities #Trader:
# @dan_aykroyd &amp; #EddieMurphy's #TradingPlaces
# https://t.co/X3POOEItMV
# https://t.co/Fu3jtI6C4J
# ワイ首だけで活動してる
# RT @ultimateholland: marvel be like:
#
# ultron? TONY'S FAULT
# civil war? TONY'S FAULT
# RT @a7mdzaher: قالي يعني اللي طلبو الاهتمام جالهم أوي
# @samimast YES. Literally just read a history book.
# RT @nnoramn: เป็นคนซ้ำๆซากๆกับอะไรที่ชอบเหมือนกัน ฟังเพลงวนๆ อาหารก็กินซ้ำเดิมทั้งอาทิตย์ได้อะ
# RT @lxi_2ll: اجمل شيلة بتسمعها || والله مابي شي منه كانه مقفي || اداء ( ظافر الحبابي )  2017 | يبطون يبطون https://t.co/fBJ7P4hyU2
# RT @suzu17_: ต้องไปฝึกความอดทนใหม่
# RT @MrFilmkritik: Disney executive: I need ideas, people. Big ideas!
#
# Employee: What if we did all of our movies…again.
#
# Disney execu…
# RT @Somospatagonia: Comienza la semana con este paisaje de la Patagonia! https://t.co/SQHhr4BMwu

# %% [markdown]
# We can restrict the location to be more-likely to get English-language tweets.

# %%
from itertools import islice  # Question: what does islice do?

r_stream = requests.post('https://stream.twitter.com/1.1/statuses/filter.json', auth=auth,
                          stream=True, data={"locations" : "-125,23,-70,50"} )
for line in islice(r_stream.iter_lines(), 100):
    # filter out keep-alive new lines
    if not line:
        continue
    tweet = json.loads(line)
    if 'text' in tweet:
        print tweet['text']
    sys.stdout.flush()
# Out:
# Ministry of Environment &amp; Climate Change ... when you are so use to saying MOE instead of MOE CC ... #EnvironmentalTechnologyStudentPorblems
# I know I'm late. It #happybirthday to my #beautiful niece #HannahMartin. #loveyou #family #diva… https://t.co/f8jDB4z35o
# Physically dead
# @SalisburyBrooke AYYY 🤙🏼
# always https://t.co/uTIY4yqU95
# Tuesdays are for Tuna.
# Akami Tuna from @haistkitchenus: yellowfin🐟wasabi soy🐟pickled jicama🐟red cabbage🐟cucumber🐟r… https://t.co/nSv2XyHl8I
# I'm at Mercadito Del Martes https://t.co/HU5p0bBGec
# I'm too sensitive
# It's annoying
# Los amoooo😍😍 https://t.co/OBtQqcTO0L
# 😳😳 Dylan's troll face though. 😂😂😂😭😭😭💔💔 https://t.co/V41knPQRJp
# I want some pizza 👀
# #RHOA star @PhaedraParks is in town with @RepWilson to talk ways to "uplift communities". Scoop @hunterschwarz &amp;… https://t.co/iRx5iWdFRm
# 😍😍😍 https://t.co/ZTEWnNPpCJ
# My second toe hurt so bad I wanna just chop it off
# @kcrock0410 wait till he starts to email winking faces to you and say things like "only the REAL OG"
# Fiona a Great Pyrenees/Golden Retriever cross visited our office today. She visits assisted living/nursing homes, h… https://t.co/JpTdWXPT88
# Everything hurts and I want to sleep forever.
# @lyssapeter055 @jaammie_ they get me 😂 https://t.co/InXoAZIfPf
# #Deathhouse https://t.co/1Xb5CZUvM3
# Thanks for the shout out @StephenAtHome #GoGamecocks!
# My exact mood https://t.co/1vzv5eFVM8
# It will be a fine squad up movie sir https://t.co/TNU8wBVNXJ
# @hopeparkerrr happy bday hopey 😍😍 hope you have the greatest day ever‼️ love you tons💘✊🏽 https://t.co/ueFCjI0f55
# @HarrisJOfficial sit on it
# Thanks so much for the follow! @moongenes We look forward to your insights!
# I literally been up all night. I finished my lab report at 3:30am and then it crashed and couldn't recover it so I had to start over 😔
# still here
# I need another week break. I feel so piled up rn 😭
# Want to work at RR Donnelley? We're #hiring in #Smyrna, TN! Click for details: https://t.co/k5UEzgKj28 #Labor #Job #Jobs #CareerArc
# 2017 women need to chill .
# Finally about to board plane!! Yeah
# Rip doc you'll be missed man. Great person and a great role model #rip☝️
# i hate underclass men 😂😂😂😂 SO MUCH
# Michelle Obama https://t.co/1lhJsDMjNl
# Trump administration sought to block Sally Yates from testifying to Congress on Russia
# https://t.co/CLRmlvG2yB
#
# Criminals. Sad. 👎👎👎😕😕😕😟😟😟
# Everyone boy or girl in general should be afraid when I hit that pool area aha https://t.co/r16frFUm3z
# ❗️COACH Z BASKETBALL 🏀 CAMP DATES ANNOUNCED❗️Registration available at https://t.co/j483m6yy6L https://t.co/zEa4sGUSud
# This #job might be a great fit for you: Spectrum Store Associate - https://t.co/fCusH4JKG0 #Retail #Bradenton, FL #Hiring #CareerArc
# Asamblea de Presidentes de @LigaMexBeis ratifican a @GeneralesdDgo y otros importantes puntos https://t.co/KBq3K7SzFV
# Way to expensive! https://t.co/yts99xBjYA
# @izzynobre esse seu video com kinder ovo ai tem alguma relaçao com a vespera do easter ai?
# i can't keep a sc streak to save my life lmao
# @jessiebridges80 @PriceSjrw5614 @FoxNews @SpeakerRyan because it works! An insurance based healthcare does not, tha… https://t.co/q8TUDEege5
# 21st * https://t.co/kbRsSZL6dt
# @CHIEFreally change the audio to mono
# thx kenz love u ❣ https://t.co/ECgWz0tnaM
# He has autism. 😕 https://t.co/Ae9OopziaV
# @MayorOfLA here i wrote this https://t.co/jUQcUJDm20
# @benson1205 :) https://t.co/We6wsDhBNM
# ¿A quién te mueres por ver en el escenario de los Premios Billboard 2017?  https://t.co/oXh2Ikbp4a
# VOTA X MALUMA2
# Mass GOP wants to talk about health care. Too soon?  #mapoli
# Friends, I just discovered today's exclusive online Beauty Steal! Tweet #21DaysofBeauty to see it for yourself! https://t.co/a61L7b5q4U
# @JamesRidyard interesting. Never thought of it that way.
# Inch by inch https://t.co/U4kgLfKLVx
# @cschultz0 I think all moms love @turnoverva
# "We've had five 100-year floods over the past 17 years in parts of Eastern NC. We knew we had to do something more." https://t.co/SDbGJhLSyv
# Thanks Conner!! https://t.co/kdodh7ZcOc
# @be_nimble Not all the time.
# @Did_I_Studda @BobbyBeltTX bwhaha
# @CoachKandJoe 👍
# Man that nigga got shot 6 times in crossfire 🤔🤔 they was aiming for that nigga lol https://t.co/M6LtLWZXk8
# Probably gon cop the red iPhone. That ho pretty
# mad about "began" now
# These four years are going to be such a blur soon. Can you believe we won't have a president for this long? Crazy.

# %% [markdown]
# ## API Request Limitations
#
# Some Authenticated APIs have hard limits on the total number of requests that can be made by one user in one day. An API service that uses a Fremium or Paid service model will enforce a limit so they can encourage high-volume users to pay for better data access. API providers also do this to force software developers to be disciplined and thoughtful in their use of the API service.
#
# All APIs might have soft limits based on some ambiguous definition of excessive use. Google, for example, will block your IP address if you make too many requests to their services too quickly. Presumably this is done with a machine learning algorithm built specifically for this purpose. Bloomberg has a Python API associated with their desktop terminal application. They will revoke access if you exceed daily or monthly hard limits, but unfortunately specifics of those limits are not shared with any of their users.
#
# These limits create challenges for the cost-conscious data scientist. Happily, Python has tools to help. One of them is the [ediblepickle](https://pypi.python.org/pypi/ediblepickle/1.1.3) package. This package provides a  convenient facility for caching the results of function calls. This can help prevent unnecessary duplicate requests to an API.
#
# In the below example, the previous `geocode` function is modified with ediblepickle's `checkpoint` decorator. It wraps the `geocode2` function with additional functionality to cache the results of the first function call in a pickle file. The results are stored in a filename that is dependent on the function arguments.
#
# If this function is called a second time with the same function arguments, the `checkpoint` decorator will intercept the call and retrieve the results from the cached pickle file.
#
# It is important that the filename be valid filename that is unique to the function parameters. In this example, we use `urllib2.quote` to escape characters and generate a proper filename.

# %%
from ediblepickle import checkpoint
import os

cache_dir = 'cache'
if not os.path.exists(cache_dir):
    os.mkdir(cache_dir)

@checkpoint(key=lambda args, kwargs: urllib2.quote(args[0]) + '.p', work_dir=cache_dir)
def geocode2(address):
    params = { 'format'        :'json', 
               'addressdetails': 1, 
               'q'             : address}
    print 'making API request...'
    result = requests.get('http://nominatim.openstreetmap.org/search', params=params)
    print 'API request complete.'
    return result
    
address = "City Hall Park, New York, NY 10007"

# %%
# %%time

# this created the cached file. observe the creation of a new pickle file in the cache directory.
response = geocode2(address)
print response.json()

# %%
# %%time

# this reads the cached file. observe that this executes ~100x faster.
# the print statements in the geocode2 function do not appear because the function itself is not executed at all.
response = geocode2(address)
print response.json()

# %% [markdown]
# ### Exercises
#
# 1. Write a Python script that takes as input an address and outputs 50 tweets from within about 10 miles of it.
# Now modify it to return the top 10 hashtags within that 10 mile range (based on, say, a 1000 tweet sample).
# 1. You can plot maps using this [Python Package](http://peak5390.wordpress.com/2012/12/08/matplotlib-basemap-tutorial-plotting-points-on-a-simple-map/).  Get geo-located tweets from the streaming API and plot them on the map.

# %% [markdown]
# ### Further reading for this lecture
#
# To learn more about JSON (there isn't much more to know!):
#  - http://www.secretgeek.net/json_3mins.asp
#  - http://en.wikipedia.org/wiki/JSON (esp. "Data types, syntax, and examples")
#  - http://tools.ietf.org/html/rfc7159
#
# A useful tool for playing with JSON on the command line is [jq](http://stedolan.github.io/jq/).
#
# To learn more about about the prevailing design pattern ("REST") for web-based APIs:
#  - http://en.wikipedia.org/wiki/Representational_state_transfer
#
# One wildcard is the wide variety of authentication strategies employed ("basic auth", cookies, bearer token, OAuth, OAuth 2, etc.).  For several of these, the documentation at http://docs.python-requests.org/en/latest/user/authentication/ is helpful.

# %% [markdown]
# ### Exit Tickets
# 1. Explain the difference between requests.get() and requests.post().
# 2. What data structures do JSON objects in Python use?
# 3. Describe what the remote site is doing when it receives an API request from you.

# %% [markdown]
# *Copyright &copy; 2015 The Data Incubator.  All rights reserved.*
